# %% [markdown]
# <a href="https://colab.research.google.com/github/adssoccer1/twitterMiddleEastSentimentAnalyis/blob/master/updatedTwitterData3_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy  
# !pip install tweet-preprocessor
# !pip install googletrans
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: tweet-preprocessor in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: googletrans in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from googletrans) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->googletrans) (2019.11.28)

# %%
#installing necessary packages

from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import pandas as pd
import csv
import re #regular expression
from textblob import TextBlob
import string
import os



import preprocessor as p
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Twitter credentials for the app
consumer_key = "a56V4jBkD5Dd3hZTAUkQy3sQC"
consumer_secret = "wWhFQxvrTR6QypnmiGRC6EHdasFNbCYkjArnzFJzbPjtAbPxnP"
access_key= "937157479661752320-8uOFLX2lfchiCm05559dNSaCrTazjxf"
access_secret = "HarTi4CJCIu9mmZolZvn4wjKd5CsTF5FEtPjVd0gY9SVM"

# %%
import tweepy as tweepy
#pass twitter credentials to tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %%
COLS = ['id', 'created_at', 'source', 'original_text','clean_text', 'sentiment','polarity','subjectivity', 'lang',
'favorite_count', 'retweet_count', 'original_author',   'possibly_sensitive', 'hashtags',
'user_mentions', 'place', 'place_coord_boundaries']

# %%
start_date = '2020-02-20'
end_date = '2020-02-28'

# %%
#file location changed to "data/telemedicine_data_extraction/" for clearer path
kuwait_tweets = "/content/sample_data/KUWAIT_PURPLE.csv"

# %%
#HappyEmoticons
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])

# %%
# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

# %%
#combine sad and happy emoticons
emoticons = emoticons_happy.union(emoticons_sad)

# %%
#Emoji patterns
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def clean_tweets(tweet):
 
    stop_words = set(stopwords.words('arabic')) #    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(tweet)
#after tweepy preprocessing the colon symbol left remain after      #removing mentions
    tweet = re.sub(r':', '', tweet)
    tweet = re.sub(r'‚Ä¶', '', tweet)
#replace consecutive non-ASCII characters with a space
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)
#remove emojis from tweet
    tweet = emoji_pattern.sub(r'', tweet)
#filter using NLTK library append it to a string
    filtered_tweet = [w for w in word_tokens if not w in stop_words]
    filtered_tweet = []
#looping through conditions
    for w in word_tokens:
#check tokens against stop words , emoticons and punctuations
        if w not in stop_words and w not in emoticons and w not in string.punctuation:
            filtered_tweet.append(w)
    return ' '.join(filtered_tweet)
    #print(word_tokens)
    #print(filtered_sentence)return tweet

# %%
#Ar
"""http://docs.tweepy.org/en/v3.5.0/api.html Use this tweepy documentation to specify the
search. The search is interfaced with the tweepy.cursor(). can mess around with langs 
and keywords now....
"""
import googletrans
from googletrans import Translator
import copy
#translator = Translator()
import time

#set to check for duplicated tweets
setOfTweets = set()

#method write_tweets()
def write_tweets(keyword, file, numTweets):
    # If the file exists, then read the existing data from the CSV file.
    #if os.path.exists(file):
    #     df = pd.read_csv(file, header=0)
    #else:
    df = pd.DataFrame(columns=COLS)
    #page attribute in tweepy.cursor and iteration


    csvFile1 = open(file, 'a' ,encoding='utf-8') #to be used at the very end
    count = 0
    count1 = 0
    numSuccessfullyAdded = 0
    # REINITIALIZE THE API every page or google blocks us. 
    translator = Translator()
    for page in tweepy.Cursor(api.search, q=keyword, lang='ar', geocode='29.3759,47.9774,100km',
                              count=200, include_rts=False, since=start_date).pages(50):

        #housekeeping
        count = count + 1
        print("beginning page ", count, " of 50 tweets each.")
        if(numSuccessfullyAdded >= numTweets):
          break



        #this says for tweet in a page of 50 tweets
        for status in page:

            #terminate if full
            if(numSuccessfullyAdded >= numTweets):
              print("number of desired tweets fullfilled. You should have ", numSuccessfullyAdded, " tweets in your file.")
              print("TERMINATE")
              break

            count1 = count1 + 1
            print("new tweet number: ", count1)
            print("Successfully added tweets fo far: ", numSuccessfullyAdded)

            #sleep for .5 seconds to avoid over requesting from google
            time.sleep(.5)
            new_entry = []
            status = status._json
 
            ## check whether the tweet is in english or skip to the next tweet
            if status['lang'] != 'ar':
                continue
 
            #when run the code, below code replaces the retweet amount and
            #no of favorires that are changed since last download.
            if status['created_at'] in df['created_at'].values:
                i = df.loc[df['created_at'] == status['created_at']].index[0]
                if status['favorite_count'] != df.at[i, 'favorite_count'] or \
                   status['retweet_count'] != df.at[i, 'retweet_count']:
                    df.at[i, 'favorite_count'] = status['favorite_count']
                    df.at[i, 'retweet_count'] = status['retweet_count']
                continue
 
 
            #tweepy preprocessing called for basic preprocessing
            clean_text = p.clean(status['text'])

            #check the set and skip duplicate tweets even with different ids or authors
            if(clean_text in setOfTweets):
              print(clean_text)
              print("   tweet number ", count1, " has already been seen")
              continue
            setOfTweets.add(clean_text)
 
            #call clean_tweet method for extra preprocessing
            filtered_tweet=clean_tweets(clean_text)

            
            #translate the cleaned tweet using google trans
            print("   Try translating")            
            filtTweetCopy = copy.deepcopy(filtered_tweet)
            #print(filtTweetCopy)
            try:
              result = translator.translate(filtTweetCopy)
            except: 
              print("   TRANSLATION FAILED - If lots of these in a row, then google is blocking requests.")
              continue;
            print("   translating passed")
 
            #pass textBlob method for sentiment calculations
            blob = TextBlob(result.text)
            Sentiment = blob.sentiment
 
            #seperate polarity and subjectivity in to two variables
            polarity = Sentiment.polarity
            subjectivity = Sentiment.subjectivity

            print("   testing polar")
            if(polarity == 0 or subjectivity == 0):
              print("   polar failed")

              continue; 
            print("   polar passed")

            #new entry append
            new_entry += [status['id'], status['created_at'],
                          status['source'], status['text'],result.text, Sentiment,polarity,subjectivity, status['lang'],
                          status['favorite_count'], status['retweet_count']]
 
            #to append original author of the tweet
            new_entry.append(status['user']['screen_name'])
 
            try:
                is_sensitive = status['possibly_sensitive']
            except KeyError:
                is_sensitive = None
            new_entry.append(is_sensitive)
 
            # hashtagas and mentiones are saved using comma separted
            hashtags = ", ".join([hashtag_item['text'] for hashtag_item in status['entities']['hashtags']])
            new_entry.append(hashtags)
            mentions = ", ".join([mention['screen_name'] for mention in status['entities']['user_mentions']])
            new_entry.append(mentions)
 
            #get location of the tweet if possible
            try:
                location = status['user']['location']
            except TypeError:
                location = ''
            new_entry.append(location)
 
            try:
                coordinates = [coord for loc in status['place']['bounding_box']['coordinates'] for coord in loc]
            except TypeError:
                coordinates = None
            new_entry.append(coordinates)
 
            single_tweet_df = pd.DataFrame([new_entry], columns=COLS)
            #print(single_tweet_df)
            df = df.append(single_tweet_df, ignore_index=True)
            csvFile = open(file, 'a' ,encoding='utf-8')
            print("   SUCCESS with tweet: ", count1)
            numSuccessfullyAdded = numSuccessfullyAdded + 1
    df.to_csv(csvFile1, mode='a', columns=COLS, index=False, encoding="utf-8")

# %%
iran_sentiment_keywords = '#إيران'

# %%
#The tweets content will only be printed if it is a duplicate so if a 
#bunch of the same tweets are printed then that means duplicate detection
#is working. Everything else that is printed should be self explanatory. 
#Downloading can take a while now, so the printed "successfully added tweets so far"
#statement will tell you how far away you are from your max_number_of desired_tweets. 



#change this number to limit the number of tweets you want to pull. 
max_number_of_tweets_desired = 20


#call main method passing keywords and file path
write_tweets(iran_sentiment_keywords,  kuwait_tweets, max_number_of_tweets_desired)
# Out:
# beginning page  1  of 50 tweets each.
# new tweet number:  1
# Successfully added tweets fo far:  0
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  1
# new tweet number:  2
# Successfully added tweets fo far:  1
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  2
# new tweet number:  3
# Successfully added tweets fo far:  2
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  3  has already been seen
# new tweet number:  4
# Successfully added tweets fo far:  2
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  4
# new tweet number:  5
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  5  has already been seen
# new tweet number:  6
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  6  has already been seen
# new tweet number:  7
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  7  has already been seen
# new tweet number:  8
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  8  has already been seen
# new tweet number:  9
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  9  has already been seen
# new tweet number:  10
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  10  has already been seen
# new tweet number:  11
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  11  has already been seen
# new tweet number:  12
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  12  has already been seen
# new tweet number:  13
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  13  has already been seen
# new tweet number:  14
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  14  has already been seen
# new tweet number:  15
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  15  has already been seen
# new tweet number:  16
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  16  has already been seen
# new tweet number:  17
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  17  has already been seen
# new tweet number:  18
# Successfully added tweets fo far:  3
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  19
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  19  has already been seen
# new tweet number:  20
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  20  has already been seen
# new tweet number:  21
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  21  has already been seen
# new tweet number:  22
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  22  has already been seen
# new tweet number:  23
# Successfully added tweets fo far:  3
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  24
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  24  has already been seen
# new tweet number:  25
# Successfully added tweets fo far:  3
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  26
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  26  has already been seen
# new tweet number:  27
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  27  has already been seen
# new tweet number:  28
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  28  has already been seen
# new tweet number:  29
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  29  has already been seen
# new tweet number:  30
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  30  has already been seen
# new tweet number:  31
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  31  has already been seen
# new tweet number:  32
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  32  has already been seen
# new tweet number:  33
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  33  has already been seen
# new tweet number:  34
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  34  has already been seen
# new tweet number:  35
# Successfully added tweets fo far:  3
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  35  has already been seen
# new tweet number:  36
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  36  has already been seen
# new tweet number:  37
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  37  has already been seen
# new tweet number:  38
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  38  has already been seen
# new tweet number:  39
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  39  has already been seen
# new tweet number:  40
# Successfully added tweets fo far:  3
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  40  has already been seen
# new tweet number:  41
# Successfully added tweets fo far:  3
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  41
# new tweet number:  42
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  42  has already been seen
# new tweet number:  43
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  43  has already been seen
# new tweet number:  44
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  44  has already been seen
# new tweet number:  45
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  45  has already been seen
# new tweet number:  46
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  46  has already been seen
# new tweet number:  47
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  47  has already been seen
# new tweet number:  48
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  48  has already been seen
# new tweet number:  49
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  49  has already been seen
# new tweet number:  50
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  50  has already been seen
# new tweet number:  51
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  51  has already been seen
# new tweet number:  52
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  52  has already been seen
# new tweet number:  53
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  53  has already been seen
# new tweet number:  54
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  54  has already been seen
# new tweet number:  55
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  55  has already been seen
# new tweet number:  56
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  56  has already been seen
# new tweet number:  57
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  57  has already been seen
# new tweet number:  58
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  58  has already been seen
# new tweet number:  59
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  59  has already been seen
# new tweet number:  60
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  60  has already been seen
# new tweet number:  61
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  61  has already been seen
# new tweet number:  62
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  62  has already been seen
# new tweet number:  63
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  63  has already been seen
# new tweet number:  64
# Successfully added tweets fo far:  4
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  64  has already been seen
# new tweet number:  65
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  65  has already been seen
# new tweet number:  66
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  66  has already been seen
# new tweet number:  67
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  67  has already been seen
# new tweet number:  68
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  68  has already been seen
# new tweet number:  69
# Successfully added tweets fo far:  4
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  69  has already been seen
# new tweet number:  70
# Successfully added tweets fo far:  4
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  70
# new tweet number:  71
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  71  has already been seen
# new tweet number:  72
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  72  has already been seen
# new tweet number:  73
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  73  has already been seen
# new tweet number:  74
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  74  has already been seen
# new tweet number:  75
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  75  has already been seen
# new tweet number:  76
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  76  has already been seen
# new tweet number:  77
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  77  has already been seen
# new tweet number:  78
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  78  has already been seen
# new tweet number:  79
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  79  has already been seen
# new tweet number:  80
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  80  has already been seen
# new tweet number:  81
# Successfully added tweets fo far:  5
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  81  has already been seen
# new tweet number:  82
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  82  has already been seen
# new tweet number:  83
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  83  has already been seen
# new tweet number:  84
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  84  has already been seen
# new tweet number:  85
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  85  has already been seen
# new tweet number:  86
# Successfully added tweets fo far:  5
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  86  has already been seen
# new tweet number:  87
# Successfully added tweets fo far:  5
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  87
# new tweet number:  88
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  88  has already been seen
# new tweet number:  89
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  89  has already been seen
# new tweet number:  90
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  90  has already been seen
# new tweet number:  91
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  91  has already been seen
# new tweet number:  92
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  92  has already been seen
# new tweet number:  93
# Successfully added tweets fo far:  6
# : ️ مختصر عن أهم الأحداث و "فك شفرة" ما يدور حولنا ️
#    tweet number  93  has already been seen
# new tweet number:  94
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  94  has already been seen
# new tweet number:  95
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  95  has already been seen
# new tweet number:  96
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  96  has already been seen
# new tweet number:  97
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  97  has already been seen
# new tweet number:  98
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  98  has already been seen
# new tweet number:  99
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  99  has already been seen
# new tweet number:  100
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  100  has already been seen
# beginning page  2  of 50 tweets each.
# new tweet number:  101
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  101  has already been seen
# new tweet number:  102
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  102  has already been seen
# new tweet number:  103
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  103  has already been seen
# new tweet number:  104
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  104  has already been seen
# new tweet number:  105
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  105  has already been seen
# new tweet number:  106
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  106  has already been seen
# new tweet number:  107
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  107  has already been seen
# new tweet number:  108
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  108  has already been seen
# new tweet number:  109
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  109  has already been seen
# new tweet number:  110
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  110  has already been seen
# new tweet number:  111
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  111  has already been seen
# new tweet number:  112
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  112  has already been seen
# new tweet number:  113
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  113  has already been seen
# new tweet number:  114
# Successfully added tweets fo far:  6
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  114  has already been seen
# new tweet number:  115
# Successfully added tweets fo far:  6
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  115
# new tweet number:  116
# Successfully added tweets fo far:  7
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  116  has already been seen
# new tweet number:  117
# Successfully added tweets fo far:  7
# : قوات الامن الإيرانية تشتبك مع جموع من البسطاء لمنعهم من دخول المزارات والأضرحة بمشهد وقم! غسلوا عقولهم عقودًا بأن هذه ال…
#    tweet number  117  has already been seen
# new tweet number:  118
# Successfully added tweets fo far:  7
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  118
# new tweet number:  119
# Successfully added tweets fo far:  8
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  119
# new tweet number:  120
# Successfully added tweets fo far:  9
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  120
# new tweet number:  121
# Successfully added tweets fo far:  10
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  121
# new tweet number:  122
# Successfully added tweets fo far:  11
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  122
# new tweet number:  123
# Successfully added tweets fo far:  12
# : ارتفاع وفيات في إلى والإصابات
#    tweet number  123  has already been seen
# new tweet number:  124
# Successfully added tweets fo far:  12
# : ارتفاع وفيات في إلى والإصابات
#    tweet number  124  has already been seen
# new tweet number:  125
# Successfully added tweets fo far:  12
# : ارتفاع وفيات في إلى والإصابات
#    tweet number  125  has already been seen
# new tweet number:  126
# Successfully added tweets fo far:  12
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  126
# new tweet number:  127
# Successfully added tweets fo far:  13
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  127
# new tweet number:  128
# Successfully added tweets fo far:  14
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  128
# new tweet number:  129
# Successfully added tweets fo far:  15
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  129
# new tweet number:  130
# Successfully added tweets fo far:  16
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  131
# Successfully added tweets fo far:  16
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  131
# new tweet number:  132
# Successfully added tweets fo far:  17
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  132
# new tweet number:  133
# Successfully added tweets fo far:  18
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  134
# Successfully added tweets fo far:  18
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  134
# new tweet number:  135
# Successfully added tweets fo far:  19
# : في محنه عصيبه لا نتمناها لاحد و الشعب الايراني اخر هـم الملالي . عندما يذرف الطبيب دموعه فأعلم…
#    tweet number  135  has already been seen
# new tweet number:  136
# Successfully added tweets fo far:  19
#    Try translating
#    translating passed
#    testing polar
#    polar failed
# new tweet number:  137
# Successfully added tweets fo far:  19
#    Try translating
#    translating passed
#    testing polar
#    polar passed
#    SUCCESS with tweet:  137
# number of desired tweets fullfilled. You should have  20  tweets in your file.
# TERMINATE
# beginning page  3  of 50 tweets each.

# %%
from google.colab import files
files.download('/content/sample_data/KUWAIT_PURPLE.csv')
